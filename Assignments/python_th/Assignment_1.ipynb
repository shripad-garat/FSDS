# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -88.8
# -
# /
#     +
# 6
#
# Answer:
#
# integer = -88.8 : 6
# string = 'hello'
# expression = - : / : +
#
#
# 2.  What is the difference between string and variable?
#
# Answer: Variable is contaner in which we store the data/ values and  String is data type it's usually words, enclosed with "" Eg String x ="Hello world" here x is the variable which is used for storing a data type of string.
#
#
# 3. Describe three different data types.
#
# Answer:
#
# str = String :  String is usually words, enclosed with "" Eg String x ="Hello world"
# int = Integer : Integer is whole no. numeric value and it can be +ve , -ve or zero.
# float = Float : Float is a numeric value with decimal point ('.').
#
# 4. What is an expression made up of? What do all expressions do?
#
# Answer:  An expression is made up of variable, method, and operator which is constructed in a way such that it can perform a perticular task.
# for eg.
# 5 * 5
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Answer:
# An expression usually refers to a piece of code that can be evaluated to a value, and is composed of variables, operators,methods.
# where as a statement refers to a piece of code that executes a specific instruction or tells the computer to complete a task.
#
#
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Answer:
# bacon value will remain same since the value is not re asigned to the bacon.
#
#
#
#
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Answer:
# the output for the both statement will be
# 'spamspamspam'
#
# 8. Why is eggs a valid variable name while 100 is invalid?
#
#
# Answer: By the rles of nomanclecture in python 'eggs' is valid name since it don't have any invalid syntex. where as 100 is numeric value which is invalid syntex for nomancleture.
#
#
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Answer:
# The int() , float() , and str( ) functions will evaluate to the integer, floating-point number, and string versions of the value passed to them.
#
# 10. Why does this expression cause an error? How can you fix it?
#
# 'I have eaten' + 99 + 'burritos.'
#
# Answer:
# Error : can only concatenate str (not "int") to str
#     which is ocured by 99 which is numeric value and only string value can be concatenate to resolve it we can put 99 in str()
#     i.e. 'I have eaten' + str(99) + 'burritos.'
